# %% [markdown]
# # Music Video Analysis
#
# In this notebook, different video features will be extracted from the music videos.

# %%
# Imports
# General data science purposes
import pandas as pd
import numpy as np
from tqdm.auto import tqdm

# For scenedetection
from scenedetect import VideoManager
from scenedetect import SceneManager
from scenedetect.detectors import ContentDetector

# For image processing
import cv2

# %%
df = pd.read_csv('music_videos_v3.csv')

# %% [markdown]
# Possible features:
# - motion intensity (average and standard error of normalized difference between frames)
# - shots/frames (the amount of shots normalized to the amount of frames in the video)
# - lighting
# - saturation
# - color energy
# - colorfulness

# %%
# Scene detection function
def find_scenes(video_path, threshold=30.0):
    video_manager = VideoManager([video_path])
    scene_manager = SceneManager()
    scene_manager.add_detector(
        ContentDetector(threshold=threshold))
    base_timecode = video_manager.get_base_timecode()
    video_manager.set_downscale_factor()
    video_manager.start()
    scene_manager.detect_scenes(frame_source=video_manager, show_progress=False)
    scene_list = scene_manager.get_scene_list(base_timecode)
    return scene_list

# %%
# Amount of frames function
def amount_frames(video_path):
    cap = cv2.VideoCapture(video_path)  
    TOTAL_FRAMES = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    return TOTAL_FRAMES

# %%
# 1 frame per second function
def frame_per_sec(cap):
    TOTAL_FRAMES = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    FRAME_RATE = round(cap.get(5)) 
    selected_frames = np.cumsum([FRAME_RATE for i in range(int(TOTAL_FRAMES / FRAME_RATE)) ])
    frames = []
    for frame in tqdm(selected_frames):
        cap.set(cv2.CAP_PROP_POS_FRAMES,frame)
        ret, frame = cap.read()
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frames.append(frame)
    return frames

# %%
# motion intensity function
def motion_intensity(frames):
    """
    Adapted from https://www.codespeedy.com/motion-detection-using-opencv-in-python/
    """
    diff = []
    for i in range(len(frames)-1):
        gray1 = cv2.cvtColor(frames[i], cv2.COLOR_BGR2GRAY)
        gray1 = cv2.GaussianBlur(gray1, (25, 25), 0)
        gray2 = cv2.cvtColor(frames[i+1], cv2.COLOR_BGR2GRAY)
        gray2 = cv2.GaussianBlur(gray2, (21, 21), 0)
        deltaframe=cv2.norm(gray1,gray2,cv2.NORM_L1)/(255*len(gray1)*len(gray1[0])) #Sum of absolute difference normalized by
                                                                    # grayscale values and amount of pixels
        diff.append(deltaframe)
    ave_diff = np.mean(diff)
    std_diff = np.std(diff)
    return ave_diff, std_diff

# %%
# lighting metric function
def lighting_bin(hls):
    l = hls[:,:,1]
    bins = np.linspace(1, 255, 21)
    flat = [val for sublist in l for val in sublist]
    digitized = np.digitize(flat, bins)
    count = np.bincount(digitized)
    lighting = sum([count[i]*(i-6) for i in range(7, len(count))]) - sum([count[i]*(7-j) for j in range(7)])
    return lighting

# %%
# mean lighting function
def lighting_mean(hls):
    l = [int(x[1]) for sublist in hls for x in sublist]
    mean = np.mean(l)
    return mean

# %%
# saturation metric function
def saturation_bin(hls):
    s = hls[:,:,2]
    bins = np.linspace(1, 255, 21)
    flat = [val for sublist in s for val in sublist]
    digitized = np.digitize(flat, bins)
    count = np.bincount(digitized)
    saturation = sum([count[i]*(i-9) for i in range(10, len(count))]) - sum([count[j]*(10-i) for j in range(10)])
    return saturation

# %%
# mean lighting function
def saturation_mean(hls):
    s = [int(x[2]) for sublist in hls for x in sublist]
    mean = np.mean(s)
    return mean

# %%
# color energy function
def color_energy(hls):
    sl = [int(x[1])*int(x[2]) for sublist in hls for x in sublist]
    h_std = np.std([x[0] for sublist in hls for x in sublist])
    color_energy = sum(sl)/(h_std*len(sl))
    return color_energy

# %%
# colorfulness functions
def image_colorfulness(image):
    """"
    Taken from https://www.pyimagesearch.com/2017/06/05/computing-image-colorfulness-with-opencv-and-python/, 
    based on Hassler & Süsstrunk
    """
    # split the image into its respective RGB components
    (B, G, R) = cv2.split(image.astype("float"))
    # compute rg = R - G
    rg = np.absolute(R - G)
    # compute yb = 0.5 * (R + G) - B
    yb = np.absolute(0.5 * (R + G) - B)
    # compute the mean and standard deviation of both `rg` and `yb`
    (rbMean, rbStd) = (np.mean(rg), np.std(rg))
    (ybMean, ybStd) = (np.mean(yb), np.std(yb))
    # combine the mean and standard deviations
    stdRoot = np.sqrt((rbStd ** 2) + (ybStd ** 2))
    meanRoot = np.sqrt((rbMean ** 2) + (ybMean ** 2))
    # derive the "colorfulness" metric and return it
    return stdRoot + (0.3 * meanRoot)

# %%
video_length = []
scene_count = []
frame_count = []
mot_int_mean = []
mot_int_std = []
lighting_met = []
light_mean = []
sat_met = []
sat_mean = []
col_en = []
colness = []

for k, path in enumerate(tqdm(df.path.values)):
    cap = cv2.VideoCapture(path)
    TOTAL_FRAMES = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    scene_list = find_scenes(path)
    scene_count.append(len(scene_list))
    frame_count.append(amount_frames(path))
    shots = []
    shot_length = []
    for start_time, end_time in scene_list:
        duration = end_time - start_time
        frame = (start_time.get_frames() + int(duration.get_frames() / 2))
        cap.set(cv2.CAP_PROP_POS_FRAMES,frame)
        ret, frame = cap.read()
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        shots.append(frame)
        shot_length.append(duration.get_seconds())
    
    frames = frame_per_sec(cap)                   
    video_length.append(len(frames))
    
    mot_int = motion_intensity(frames)
    mot_int_mean.append(mot_int[0])
    mot_int_std.append(mot_int[1])
    
    lighting_met_i = []
    light_mean_i = []
    sat_met_i = []
    sat_mean_i = []
    col_en_i = []
    colness_i = []
    
    for frame in tqdm(shots):
        hls = cv2.cvtColor(frame, cv2.COLOR_BGR2HLS)
        
        lighting_met_i.append(lighting_bin(hls))
        light_mean_i.append(lighting_mean(hls))
        sat_met_i.append(saturation_bin(hls))
        sat_mean_i.append(saturation_mean(hls))
        col_en_i.append(color_energy(hls))
        colness_i.append(image_colorfulness(frame))
    
    lighting_met.append(np.average(lighting_met_i, weights=shot_length))
    light_mean.append(np.average(light_mean_i, weights=shot_length))
    sat_met.append(np.average(sat_met_i, weights=shot_length))
    sat_mean .append(np.average(sat_mean_i, weights=shot_length))
    col_en.append(np.average(col_en_i, weights=shot_length))
    colness.append(np.average(colness_i, weights=shot_length))
# Out:
#   0%|          | 0/997 [00:00<?, ?it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
#   0%|          | 0/65 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
#   0%|          | 0/251 [00:00<?, ?it/s]
#   0%|          | 0/93 [00:00<?, ?it/s]
#   0%|          | 0/192 [00:00<?, ?it/s]
#   0%|          | 0/115 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
#   0%|          | 0/86 [00:00<?, ?it/s]
#   0%|          | 0/277 [00:00<?, ?it/s]
#   0%|          | 0/120 [00:00<?, ?it/s]
#   0%|          | 0/190 [00:00<?, ?it/s]
#   0%|          | 0/146 [00:00<?, ?it/s]
#   0%|          | 0/205 [00:00<?, ?it/s]
#   0%|          | 0/120 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-96-2fd6d363f60b> in <module>
#      50         sat_met_i.append(saturation_bin(hls))
#      51         sat_mean_i.append(saturation_mean(hls))
# ---> 52         col_en_i.append(color_energy(hls))
#      53         colness_i.append(image_colorfulness(frame))
#      54
#
# <ipython-input-71-c6a9fb11b7c3> in color_energy(frame)
#       3     hls = cv2.cvtColor(frame, cv2.COLOR_BGR2HLS)
#       4     sl = [int(x[1])*int(x[2]) for sublist in hls for x in sublist]
# ----> 5     h_std = np.std([x[0] for sublist in hls for x in sublist])
#       6     color_energy = sum(sl)/(h_std*len(sl))
#       7     return color_energy
#
# KeyboardInterrupt:

# %%
frames = frame_per_sec(df.path[2])
# Out:
#   0%|          | 0/251 [00:00<?, ?it/s]

# %%
hls = cv2.cvtColor(frames[5], cv2.COLOR_BGR2HLS)
lighting_bin(hls)
# Out:
# 213808

# %%
scene_list
# Out:
# [(FrameTimecode(frame=0, fps=29.970030),
#   FrameTimecode(frame=18, fps=29.970030)),
#  (FrameTimecode(frame=18, fps=29.970030),
#   FrameTimecode(frame=42, fps=29.970030)),
#  (FrameTimecode(frame=42, fps=29.970030),
#   FrameTimecode(frame=64, fps=29.970030)),
#  (FrameTimecode(frame=64, fps=29.970030),
#   FrameTimecode(frame=87, fps=29.970030)),
#  (FrameTimecode(frame=87, fps=29.970030),
#   FrameTimecode(frame=162, fps=29.970030)),
#  (FrameTimecode(frame=162, fps=29.970030),
#   FrameTimecode(frame=372, fps=29.970030)),
#  (FrameTimecode(frame=372, fps=29.970030),
#   FrameTimecode(frame=483, fps=29.970030)),
#  (FrameTimecode(frame=483, fps=29.970030),
#   FrameTimecode(frame=650, fps=29.970030)),
#  (FrameTimecode(frame=650, fps=29.970030),
#   FrameTimecode(frame=699, fps=29.970030)),
#  (FrameTimecode(frame=699, fps=29.970030),
#   FrameTimecode(frame=937, fps=29.970030)),
#  (FrameTimecode(frame=937, fps=29.970030),
#   FrameTimecode(frame=1008, fps=29.970030)),
#  (FrameTimecode(frame=1008, fps=29.970030),
#   FrameTimecode(frame=1186, fps=29.970030)),
#  (FrameTimecode(frame=1186, fps=29.970030),
#   FrameTimecode(frame=1210, fps=29.970030)),
#  (FrameTimecode(frame=1210, fps=29.970030),
#   FrameTimecode(frame=1239, fps=29.970030)),
#  (FrameTimecode(frame=1239, fps=29.970030),
#   FrameTimecode(frame=1263, fps=29.970030)),
#  (FrameTimecode(frame=1263, fps=29.970030),
#   FrameTimecode(frame=1332, fps=29.970030)),
#  (FrameTimecode(frame=1332, fps=29.970030),
#   FrameTimecode(frame=1529, fps=29.970030)),
#  (FrameTimecode(frame=1529, fps=29.970030),
#   FrameTimecode(frame=1709, fps=29.970030)),
#  (FrameTimecode(frame=1709, fps=29.970030),
#   FrameTimecode(frame=1737, fps=29.970030)),
#  (FrameTimecode(frame=1737, fps=29.970030),
#   FrameTimecode(frame=1831, fps=29.970030)),
#  (FrameTimecode(frame=1831, fps=29.970030),
#   FrameTimecode(frame=2028, fps=29.970030)),
#  (FrameTimecode(frame=2028, fps=29.970030),
#   FrameTimecode(frame=2056, fps=29.970030)),
#  (FrameTimecode(frame=2056, fps=29.970030),
#   FrameTimecode(frame=2116, fps=29.970030)),
#  (FrameTimecode(frame=2116, fps=29.970030),
#   FrameTimecode(frame=2168, fps=29.970030)),
#  (FrameTimecode(frame=2168, fps=29.970030),
#   FrameTimecode(frame=2217, fps=29.970030)),
#  (FrameTimecode(frame=2217, fps=29.970030),
#   FrameTimecode(frame=2237, fps=29.970030)),
#  (FrameTimecode(frame=2237, fps=29.970030),
#   FrameTimecode(frame=2275, fps=29.970030)),
#  (FrameTimecode(frame=2275, fps=29.970030),
#   FrameTimecode(frame=2414, fps=29.970030)),
#  (FrameTimecode(frame=2414, fps=29.970030),
#   FrameTimecode(frame=2492, fps=29.970030)),
#  (FrameTimecode(frame=2492, fps=29.970030),
#   FrameTimecode(frame=2522, fps=29.970030)),
#  (FrameTimecode(frame=2522, fps=29.970030),
#   FrameTimecode(frame=2549, fps=29.970030)),
#  (FrameTimecode(frame=2549, fps=29.970030),
#   FrameTimecode(frame=2682, fps=29.970030)),
#  (FrameTimecode(frame=2682, fps=29.970030),
#   FrameTimecode(frame=3005, fps=29.970030)),
#  (FrameTimecode(frame=3005, fps=29.970030),
#   FrameTimecode(frame=3121, fps=29.970030)),
#  (FrameTimecode(frame=3121, fps=29.970030),
#   FrameTimecode(frame=3234, fps=29.970030)),
#  (FrameTimecode(frame=3234, fps=29.970030),
#   FrameTimecode(frame=3255, fps=29.970030)),
#  (FrameTimecode(frame=3255, fps=29.970030),
#   FrameTimecode(frame=3271, fps=29.970030)),
#  (FrameTimecode(frame=3271, fps=29.970030),
#   FrameTimecode(frame=3324, fps=29.970030)),
#  (FrameTimecode(frame=3324, fps=29.970030),
#   FrameTimecode(frame=3430, fps=29.970030)),
#  (FrameTimecode(frame=3430, fps=29.970030),
#   FrameTimecode(frame=3534, fps=29.970030)),
#  (FrameTimecode(frame=3534, fps=29.970030),
#   FrameTimecode(frame=3640, fps=29.970030)),
#  (FrameTimecode(frame=3640, fps=29.970030),
#   FrameTimecode(frame=3668, fps=29.970030)),
#  (FrameTimecode(frame=3668, fps=29.970030),
#   FrameTimecode(frame=3814, fps=29.970030)),
#  (FrameTimecode(frame=3814, fps=29.970030),
#   FrameTimecode(frame=4257, fps=29.970030)),
#  (FrameTimecode(frame=4257, fps=29.970030),
#   FrameTimecode(frame=4325, fps=29.970030)),
#  (FrameTimecode(frame=4325, fps=29.970030),
#   FrameTimecode(frame=4408, fps=29.970030)),
#  (FrameTimecode(frame=4408, fps=29.970030),
#   FrameTimecode(frame=4439, fps=29.970030)),
#  (FrameTimecode(frame=4439, fps=29.970030),
#   FrameTimecode(frame=4461, fps=29.970030)),
#  (FrameTimecode(frame=4461, fps=29.970030),
#   FrameTimecode(frame=4490, fps=29.970030)),
#  (FrameTimecode(frame=4490, fps=29.970030),
#   FrameTimecode(frame=4564, fps=29.970030)),
#  (FrameTimecode(frame=4564, fps=29.970030),
#   FrameTimecode(frame=4592, fps=29.970030)),
#  (FrameTimecode(frame=4592, fps=29.970030),
#   FrameTimecode(frame=4632, fps=29.970030)),
#  (FrameTimecode(frame=4632, fps=29.970030),
#   FrameTimecode(frame=4657, fps=29.970030)),
#  (FrameTimecode(frame=4657, fps=29.970030),
#   FrameTimecode(frame=4738, fps=29.970030)),
#  (FrameTimecode(frame=4738, fps=29.970030),
#   FrameTimecode(frame=4859, fps=29.970030)),
#  (FrameTimecode(frame=4859, fps=29.970030),
#   FrameTimecode(frame=5009, fps=29.970030)),
#  (FrameTimecode(frame=5009, fps=29.970030),
#   FrameTimecode(frame=5103, fps=29.970030)),
#  (FrameTimecode(frame=5103, fps=29.970030),
#   FrameTimecode(frame=5149, fps=29.970030)),
#  (FrameTimecode(frame=5149, fps=29.970030),
#   FrameTimecode(frame=5182, fps=29.970030)),
#  (FrameTimecode(frame=5182, fps=29.970030),
#   FrameTimecode(frame=5230, fps=29.970030)),
#  (FrameTimecode(frame=5230, fps=29.970030),
#   FrameTimecode(frame=5292, fps=29.970030)),
#  (FrameTimecode(frame=5292, fps=29.970030),
#   FrameTimecode(frame=5334, fps=29.970030)),
#  (FrameTimecode(frame=5334, fps=29.970030),
#   FrameTimecode(frame=5375, fps=29.970030)),
#  (FrameTimecode(frame=5375, fps=29.970030),
#   FrameTimecode(frame=5414, fps=29.970030)),
#  (FrameTimecode(frame=5414, fps=29.970030),
#   FrameTimecode(frame=5516, fps=29.970030)),
#  (FrameTimecode(frame=5516, fps=29.970030),
#   FrameTimecode(frame=5749, fps=29.970030)),
#  (FrameTimecode(frame=5749, fps=29.970030),
#   FrameTimecode(frame=5795, fps=29.970030)),
#  (FrameTimecode(frame=5795, fps=29.970030),
#   FrameTimecode(frame=5835, fps=29.970030)),
#  (FrameTimecode(frame=5835, fps=29.970030),
#   FrameTimecode(frame=5912, fps=29.970030)),
#  (FrameTimecode(frame=5912, fps=29.970030),
#   FrameTimecode(frame=5936, fps=29.970030)),
#  (FrameTimecode(frame=5936, fps=29.970030),
#   FrameTimecode(frame=5997, fps=29.970030)),
#  (FrameTimecode(frame=5997, fps=29.970030),
#   FrameTimecode(frame=6065, fps=29.970030)),
#  (FrameTimecode(frame=6065, fps=29.970030),
#   FrameTimecode(frame=6084, fps=29.970030)),
#  (FrameTimecode(frame=6084, fps=29.970030),
#   FrameTimecode(frame=6105, fps=29.970030)),
#  (FrameTimecode(frame=6105, fps=29.970030),
#   FrameTimecode(frame=6128, fps=29.970030)),
#  (FrameTimecode(frame=6128, fps=29.970030),
#   FrameTimecode(frame=6145, fps=29.970030)),
#  (FrameTimecode(frame=6145, fps=29.970030),
#   FrameTimecode(frame=6677, fps=29.970030)),
#  (FrameTimecode(frame=6677, fps=29.970030),
#   FrameTimecode(frame=7556, fps=29.970030))]
